# %%
import pandas as pd

# %%
file = pd.read_csv(r"C:\\Users\\Zulfiqar\\ML Numpy\\Large Data\\CricutDesignSpace.csv")

# %%
replies = file.replyContent.dropna()

# %%
user_name = file.userName[9]
user = user_name.split()
user[0]
# Out:
# 'Heidi'

# %%
reply = list(file.replyContent[9])
type(reply)
reply
# Out:
# ['H',
#  'i',
#  ' ',
#  'H',
#  'e',
#  'i',
#  'd',
#  'i',
#  '!',
#  ' ',
#  'T',
#  'h',
#  'a',
#  'n',
#  'k',
#  ' ',
#  'y',
#  'o',
#  'u',
#  ' ',
#  's',
#  'o',
#  ' ',
#  'm',
#  'u',
#  'c',
#  'h',
#  ' ',
#  'f',
#  'o',
#  'r',
#  ' ',
#  'l',
#  'e',
#  't',
#  't',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'u',
#  's',
#  ' ',
#  'k',
#  'n',
#  'o',
#  'w',
#  ' ',
#  'a',
#  'b',
#  'o',
#  'u',
#  't',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  '.',
#  ' ',
#  'W',
#  'e',
#  ' ',
#  'a',
#  'r',
#  'e',
#  ' ',
#  'h',
#  'e',
#  'a',
#  'r',
#  't',
#  'b',
#  'r',
#  'o',
#  'k',
#  'e',
#  'n',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'h',
#  'e',
#  'a',
#  'r',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  'y',
#  'o',
#  'u',
#  ' ',
#  'h',
#  'a',
#  'v',
#  'e',
#  ' ',
#  'l',
#  'o',
#  's',
#  't',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'j',
#  'e',
#  'c',
#  't',
#  's',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'b',
#  'e',
#  'e',
#  'n',
#  ' ',
#  'd',
# ...

# %%
first_name = len(user[0])
print(first_name)
# flag = 0
for i in range(len(reply)):
#     print(reply[i])
    if(reply[i:(i+first_name)] == user[0]):
        print('yes')
# Out:
# 5

# %%
arr=[]

for reply in replies:
    print(reply)
    updated=''
    flag=0
    arr=[]
    new=''
    
    for i in range(len(reply)):
        if(reply[i] == ',' or reply[i] == '.'):
            print("llll")
            new=reply[i+1:]
            print(new)
            break
        
        
        if flag==1:
            continue
        elif reply[i]==' ':
            flag=1
        else:
            arr.append(reply[i])
        
    
    ist=' '
    for l in range(len(arr)):
        ist=ist+arr[l]
    ist=ist[1:]
#     print(ist)
    reply_splitted=reply.split(' ')
#     print(reply_splitted)
    for splitted in range(len(reply_splitted)):
        if reply_splitted[0] in ["Hi,","Hello,","Hey,"]:
            updated=ist[:]+" [username],"+new
        elif reply_splitted[0] in ["Hi","Hello","Hey"]:
            updated=ist[:]+" [username],"+new
        else:
            updated=reply
    print("00000")
    print(updated+"\n")
# Out:
# Hi Charlie! Thank you so much for sharing this information with us! We are sorry to hear that you are having this trouble getting text into your projects. We know how important this is to our projects and would love to help you get this resolved! Reach out to our Member Care team with reference: 4100589 We hope to hear from you! Cricut.com/contact
# llll
#  We know how important this is to our projects and would love to help you get this resolved! Reach out to our Member Care team with reference: 4100589 We hope to hear from you! Cricut.com/contact
# 00000
# Hi [username], We know how important this is to our projects and would love to help you get this resolved! Reach out to our Member Care team with reference: 4100589 We hope to hear from you! Cricut.com/contact
#
# ...
